# %% [markdown]
# # 1.Univariate analysis

# %% [raw]
# for univariate analasis we have to ask first question what type of data is- numerical(number-height,age,weight,etc) or categoriacal(category-sex,color, etc)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 482          483         0       3
# 299          300         1       1
# 804          805         1       3
# 517          518         0       3
# 311          312         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 482                         Rouse, Mr. Richard Henry    male  50.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 804                          Hedman, Mr. Oskar Arvid    male  27.0      0
# 517                                Ryan, Mr. Patrick    male   NaN      0
# 311                       Ryerson, Miss. Emily Borie  female  18.0      2
#
#      Parch    Ticket      Fare            Cabin Embarked
# 482      0  A/5 3594    8.0500              NaN        S
# 299      1  PC 17558  247.5208          B58 B60        C
# 804      0    347089    6.9750              NaN        S
# 517      0    371110   24.1500              NaN        Q
# ...

# %% [markdown]
# # A.Categorical data

# %% [markdown]
# ## a.countplot

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=df['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ## b.pieplot

# %%
df['Pclass'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
x=df['Pclass'].value_counts()
plt.pie(x.values,labels=x.index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # B.Numerical data

# %% [markdown]
# ## a.histplot

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## b.distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_8140\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## c.box plot

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# # 2.Bivariate Analysis

# %% [markdown]
# ## A.scatter plot - numerical vs numerical
# ## B.bar plot-numerical vs categorical
# ## C.box plot-numerical vs categorical
# ## heatmap -categorical vs categorrical
# ## clustermap- categorrical vs categorical

# %%
sns.scatterplot(x=df['PassengerId'],y=df['Age'],hue=df['Sex'])
# Out:
# <Axes: xlabel='PassengerId', ylabel='Age'>

# %%
sns.boxplot(x=df['Pclass'],y=df['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=df['Pclass'],y=df['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
